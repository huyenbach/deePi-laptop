# %% [markdown]
# ### Import dependencies

# %%
import pandas as pd
# !pip install scikit-learn
from sklearn.metrics import cohen_kappa_score, confusion_matrix, classification_report
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 48.9 MB/s eta 0:00:00
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# calculate percent agreement, Cohen's kappa, and confusion matrix

# %% [markdown]
# Load annotation csv files

# %%
ann1 = pd.read_csv("/Users/alopias/Desktop/Huyen-deePi/deePi-laptop/active_review_batch_003/current_labels.csv")
ann2 = pd.read_csv("brendan_current_labels.csv")

# Rename label columns
ann1 = ann1.rename(columns={"label": "label_1"})
ann2 = ann2.rename(columns={"label": "label_2"})

# Merge by image name to make sure labels line up correctly
df = ann1.merge(ann2, on="image", how="inner")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 9
#       5 ann1 = ann1.rename(columns={"label": "label_1"})
#       6 ann2 = ann2.rename(columns={"label": "label_2"})
#       7
#       8 # Merge by image name to make sure labels line up correctly
# ----> 9 df = ann1.merge(ann2, on="image", how="inner")
#
# File ~/Desktop/Huyen-deePi/deePi-laptop/.venv/lib/python3.13/site-packages/pandas/core/frame.py:12900, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   12896         self._check_copy_deprecation(copy)
#   12897
#   12898         from pandas.core.reshape.merge import merge
#   12899
# > 12900         return merge(
#   12901             self,
#   12902             right,
#   12903             how=how,
#
# ...
